# %% [markdown]
# <a href="https://colab.research.google.com/github/ErRaiaoh951/AICourse/blob/main/Intro_to_environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initializing connection to github : user, email...

# %%
# !git init
git config --global user.name "ErRaiaoh"
git config --global user.email "email@gmail.com"
# Out:
# Reinitialized existing Git repository in /content/.git/

# %% [markdown]
# # Nueva sección
